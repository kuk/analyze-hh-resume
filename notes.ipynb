# %%
# %matplotlib inline

# %%
# resumes = log_progress(read_resumes(RESUMES), total=TOTAL_RESUMES)
# dump_resumes(resumes)

# %%
# %run -n main.py
resumes = list(log_progress(load_resumes(), total=TOTAL_RESUMES))
# Out:
# 0.00% 0.50% 1.00% 1.50% 2.00% 2.50% 3.00% 3.50% 4.00% 4.50% 5.00% 5.50% 6.00% 6.50% 7.00% 7.50% 8.00% 8.50% 9.00% 9.50% 10.00% 10.50% 11.00% 11.50% 12.00% 12.50% 13.00% 13.50% 14.00% 14.50% 15.00% 15.50% 16.00% 16.50% 17.00% 17.50% 18.00% 18.50% 19.00% 19.50% 20.00% 20.50% 21.00% 21.50% 22.00% 22.50% 23.00% 23.50% 24.00% 24.50% 25.00% 25.50% 26.00% 26.50% 27.00% 27.50% 28.00% 28.50% 29.00% 29.50% 30.00% 30.50% 31.00% 31.50% 32.00% 32.50% 33.00% 33.50% 34.00% 34.50% 35.00% 35.50% 36.00% 36.50% 37.00% 37.50% 38.00% 38.50% 39.00% 39.50% 40.00% 40.50% 41.00% 41.50% 42.00% 42.50% 43.00% 43.50% 44.00% 44.50% 45.00% 45.50% 46.00% 46.50% 47.00% 47.50% 48.00% 48.50% 49.00% 49.50% 50.00% 50.50% 51.00% 51.50% 52.00% 52.50% 53.00% 53.50% 54.00% 54.50% 55.00% 55.50% 56.00% 56.50% 57.00% 57.50% 58.00% 58.50% 59.00% 59.50% 60.00% 60.50% 61.00% 61.50% 62.00% 62.50% 63.00% 63.50% 64.00% 64.50% 65.00% 65.50% 66.00% 66.50% 67.00% 67.50% 68.00% 68.50% 69.00% 69.50% 70.00% 70.50% 71.00% 71.50% 72.00% 72.
# ...

# %%
# %run -n main.py
areas = list(load_areas())

# %%
# %run -n main.py
russian_areas = get_russian_areas(areas)

# %%
# %run -n main.py
school_universities = load_school_universities()

# %%
# %run -n main.py
university_names = load_university_names()

# %%
# %run -n main.py
vacancies = list(log_progress(read_vacancies(), total=TOTAL_VACANCIES))
# Out:
#  0.00% 0.50% 1.00% 1.50% 2.00% 2.50% 3.00% 3.50% 4.00% 4.50% 5.00% 5.50% 6.00% 6.50% 7.00% 7.50% 8.00% 8.50% 8.99% 9.49% 9.99% 10.49% 10.99% 11.49% 11.99% 12.49% 12.99% 13.49% 13.99% 14.49% 14.99% 15.49% 15.99% 16.49% 16.99% 17.49% 17.99% 18.49% 18.99% 19.49% 19.99% 20.49% 20.99% 21.49% 21.99% 22.49% 22.99% 23.49% 23.99% 24.49% 24.99% 25.49% 25.99% 26.48% 26.98% 27.48% 27.98% 28.48% 28.98% 29.48% 29.98% 30.48% 30.98% 31.48% 31.98% 32.48% 32.98% 33.48% 33.98% 34.48% 34.98% 35.48% 35.98% 36.48% 36.98% 37.48% 37.98% 38.48% 38.98% 39.48% 39.98% 40.48% 40.98% 41.48% 41.98% 42.48% 42.98% 43.47% 43.97% 44.47% 44.97% 45.47% 45.97% 46.47% 46.97% 47.47% 47.97% 48.47% 48.97% 49.47% 49.97% 50.47% 50.97% 51.47% 51.97% 52.47% 52.97% 53.47% 53.97% 54.47% 54.97% 55.47% 55.97% 56.47% 56.97% 57.47% 57.97% 58.47% 58.97% 59.47% 59.97% 60.47% 60.96% 61.46% 61.96% 62.46% 62.96% 63.46% 63.96% 64.46% 64.96% 65.46% 65.96% 66.46% 66.96% 67.46% 67.96% 68.46% 68.96% 69.46% 69.96% 70.46% 70.96% 71.46% 71.96% 72.
# ...

# %%
# %run -n main.py
specializations = get_specializations(vacancies)

# %% [markdown]
# # Возраст

# %%
# %run -n main.py
show_age_distribution(resumes)
# Out:
# Undefined: 4.71%
# Unbound: 0.53%

# %% [markdown]
# # Пол

# %% [markdown]
# Наверное 1 — женщины

# %%
# %run -n main.py
show_gender_distribution(resumes)
# Out:
# Undefined: 1.50%

# %%
# %run -n main.py
show_gender_salary_correlation(resumes)

# %% [markdown]
# Точно 1 — женщины

# %%
# %run -n main.py
show_gender_specializations(resumes, specializations)

# %% [markdown]
# # Зарплата

# %%
# %run -n main.py
show_currency_distribution(resumes)
# Out:
# Undefined: 24.54%
# RUR from defined: 79.67%

# %%
# %run -n main.py
show_vacancy_salary_bounds_distribution(vacancies)

# %%
# %run -n main.py
show_vacancy_salary_model(vacancies)

# %% [markdown]
# # Возраст и зарплата

# %%
# %run -n main.py
show_age_salary_correlation(resumes)
# Out:
# /Users/alexkuk/envs/mypy/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# # Спрос и предложение

# %%
# %run -n main.py
show_vacancy_resume_specializations(vacancies, resumes, specializations)

# %%
# %run -n main.py
show_vacancy_resume_salaries(vacancies, resumes, specializations)

# %% [markdown]
# # География

# %%
# %run -n main.py
show_geography_salary(resumes, russian_areas)

# %%
# %run -n main.py
show_geography_specializations(resumes, russian_areas, specializations)

# %% [markdown]
# # ВУЗы

# %%
# %run -n main.py
show_university_salary(resumes, university_names)

# %%
# %run -n main.py
show_universities_specializations(resumes, university_names, specializations)

# %% [markdown]
# # Школы

# %%
# %run -n main.py
school_specializations = get_school_specializations(resumes, university_names, specializations, school_universities)

# %%
# %run -n main
show_school_specializations(school_specializations)

# %%
# %run -n main.py
dump_school_specializations(school_specializations)
