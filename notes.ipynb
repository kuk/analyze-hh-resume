# %%
# %matplotlib inline

# %%
# %run -n main.py
resumes = log_progress(read_resumes(RESUMES_SAMPLE), total=TOTAL_RESUMES)
dump_resumes(resumes)
# Out:
#  0.00% 0.50% 1.00% 1.50% 2.00% 2.50% 3.00% 3.50% 4.00% 4.50% 5.00% 5.50% 6.00% 6.50% 7.00% 7.50% 8.00% 8.50% 9.00% 9.50% 10.00% 10.50% 11.00% 11.50% 12.00% 12.50% 13.00% 13.50% 14.00% 14.50% 15.00% 15.50% 16.00%

# %%
# %run -n main.py
resumes = list(log_progress(load_resumes(), total=TOTAL_RESUMES))
# Out:
#  0.00% 0.50% 1.00% 1.50% 2.00% 2.50% 3.00% 3.50% 4.00% 4.50% 5.00% 5.50% 6.00% 6.50% 7.00% 7.50% 8.00% 8.50% 9.00% 9.50% 10.00% 10.50% 11.00% 11.50% 12.00% 12.50% 13.00% 13.50% 14.00% 14.50% 15.00% 15.50% 16.00%

# %%
len(resumes)
# Out:
# 986985

# %%
# %run -n main.py
show_age_distribution(resumes)
# Out:
# Undefined: 6.54%
# Unbound: 2.11%

# %%
# %run -n main.py
show_gender_distribution(resumes)
# Out:
# Undefined: 1.30%

# %%
# %run -n main.py
show_currency_distribution(resumes)
# Out:
# Undefined: 22.82%
# RUR from defined: 77.23%

# %%
# %run -n main.py
show_salary_distribution(resumes)
# Out:
# Undefined salary if currency defined: 0.07%
# Unbound salary if currency defined: 3.05%
